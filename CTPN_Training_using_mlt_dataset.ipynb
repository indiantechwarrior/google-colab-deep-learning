# %% [markdown]
# <a href="https://colab.research.google.com/github/indiantechwarrior/google-colab-deep-learning/blob/master/CTPN_Training_using_mlt_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This notebook illustrates how to train a CTPN Model on MLT dataset**
#
# ---

# %% [markdown]
# **Setting up Tensorflow version**

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
# !git clone https://github.com/indiantechwarrior/text-detection-ctpn.git
# Out:
# Cloning into 'text-detection-ctpn'...
# remote: Enumerating objects: 1105, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 1105 (delta 12), reused 4 (delta 1), pack-reused 1076
# Receiving objects: 100% (1105/1105), 344.24 MiB | 29.14 MiB/s, done.
# Resolving deltas: 100% (455/455), done.

# %%
import os
os.chdir("/content/text-detection-ctpn/data")

# %% [markdown]
# **Download VGG16 Pre-Trained Model**

# %%
# !wget http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# Out:
# --2021-09-19 13:57:21--  http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.6.128, 2607:f8b0:4001:c5a::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.6.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 513324920 (490M) [application/x-tar]
# Saving to: ‘vgg_16_2016_08_28.tar.gz’
#
# vgg_16_2016_08_28.t 100%[===================>] 489.54M   230MB/s    in 2.1s
#
# 2021-09-19 13:57:23 (230 MB/s) - ‘vgg_16_2016_08_28.tar.gz’ saved [513324920/513324920]

# %%
# !tar -xvf vgg_16_2016_08_28.tar.gz
# Out:
# vgg_16.ckpt

# %%
import os
os.chdir("/content/text-detection-ctpn/utils/bbox")

# %%
# !chmod +x make.sh
# !./make.sh
# Out:
# running install
# running build
# running build_ext
# building 'bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c bbox.c -o build/temp.linux-x86_64-3.7/bbox.o
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
# ...

# %% [markdown]
# **Download MLT training dataset,**
#
# Google Drive Path- https://drive.google.com/file/d/1npxA_pcEvIa4c42rho1HgnfJ7tamThSy/view

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/mlt.zip" "/content/text-detection-ctpn/data/dataset/"
# !cp "/content/drive/MyDrive/mlt.zip" "/content/text-detection-ctpn/data/"

# %%
import os
os.chdir("/content/text-detection-ctpn/data/")
# !unzip "mlt.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mlt/image/img_2374.jpg
#   inflating: mlt/image/img_2392.jpg
#   inflating: mlt/image/img_3210.jpg
#   inflating: mlt/image/img_3228.jpg
#   inflating: mlt/image/img_3246.jpg
#   inflating: mlt/image/img_3264.jpg
#   inflating: mlt/image/img_3282.jpg
#   inflating: mlt/image/img_3300.jpg
#   inflating: mlt/image/img_3318.jpg
#   inflating: mlt/image/img_3336.jpg
#   inflating: mlt/image/img_3354.jpg
#   inflating: mlt/image/img_3372.jpg
#   inflating: mlt/image/img_3390.jpg
#   inflating: mlt/image/img_3427.jpg
#   inflating: mlt/image/img_3428.jpg
#   inflating: mlt/image/img_3429.jpg
#   inflating: mlt/image/img_3430.jpg
#   inflating: mlt/image/img_3431.jpg
#   inflating: mlt/image/img_3432.jpg
#   inflating: mlt/image/img_3433.jpg
#   inflating: mlt/image/img_3434.jpg
#   inflating: mlt/image/img_3435.jpg
#   inflating: mlt/image/img_3436.jpg
#   inflating: mlt/image/img_3437.jpg
# ...

# %%
# !mv "mlt" "mlt_splitted"

# %%
import os
os.chdir("/content")
# !mkdir checkpoints_mlt

# %%
import os
os.chdir("/content/text-detection-ctpn")

# %% [markdown]
# **Training CTPN Model**

# %%
# !python ./main/train.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ./main/train.py:117: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From ./main/train.py:36: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0919 13:59:45.813869 139887351953280 module_wrapper.py:139] From ./main/train.py:36: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ./main/train.py:40: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %% [markdown]
# **Validation of test images against newly trained checkpoints**

# %%
# !python ./main/demo.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ./main/demo.py:121: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From ./main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0919 14:36:36.793014 140483857307520 module_wrapper.py:139] From ./main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From ./main/demo.py:61: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %% [markdown]
# **Zip newly trained checkpoints files**

# %%
import os
os.chdir("/content/checkpoints_mlt")
# !zip checkpoint_60000.zip checkpoint ctpn_60000.ckpt.data-00000-of-00001 ctpn_60000.ckpt.index ctpn_60000.ckpt.meta
# Out:
#   adding: checkpoint (deflated 50%)
#   adding: ctpn_60000.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: ctpn_60000.ckpt.index (deflated 66%)
#   adding: ctpn_60000.ckpt.meta (deflated 92%)

# %% [markdown]
# **Copy zipped trained checkpoints to Google Drive**

# %%
# !cp  "/content/checkpoints_mlt/checkpoint_60000.zip"  "/content/drive/MyDrive/"
